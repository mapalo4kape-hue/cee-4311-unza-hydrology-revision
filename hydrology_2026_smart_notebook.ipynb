# %% [markdown]
# # CEE 4311 Hydrology Revision Notebook (2026)
#
# **Professional lesson-plan notebook for exam preparation.**

# %% [markdown]
# ## Study Plan Structure
# - Lesson 1: Precipitation fundamentals and applications
# - Lesson 2: Rainfall measurement, gauge density, and missing data
# - Lesson 3: Infiltration concepts and field methods
# - Lesson 4: Infiltration models and parameter estimation
# - Lesson 5: Phi-index, runoff depth, and runoff coefficient
# - Lesson 6: Examination technique and answer quality

# %%
print("CEE 4311 Hydrology revision notebook is ready.")

# %% [markdown]
# # Lesson 1 — Precipitation Fundamentals
#
# ## Learning outcomes
# 1. Define precipitation in hydrologic terms.
# 2. Distinguish major precipitation forms and mechanisms.
# 3. Explain engineering relevance of precipitation data.
#
# ## Core content
# - Forms: rain, drizzle, snow, hail.
# - Typical references:
#   - Drizzle droplet diameter < 0.5 mm
#   - Hail size approximately 0.5–5 cm
#
# ## Main precipitation mechanisms
# - Convective
# - Orographic
# - Cyclonic
#
# ## Engineering relevance
# - Flood forecasting
# - Irrigation planning
# - Dam and drainage design

# %% [markdown]
# # Lesson 2 — Rainfall Measurement, Gauge Density, and Missing Data
#
# ## Instruments
# - Non-recording gauge: ordinary rain gauge
# - Recording gauges: tipping bucket, float type, weighing type
#
# ## Gauge density relation
# \[
# N = rac{CV^2}{E^2}
# \]
# where \(CV=(\sigma/ar{P})	imes 100\%\).
#
# ## Missing rainfall methods
# 1. Arithmetic mean method
# 2. Normal ratio method
# 3. Inverse distance weighting method
#
# ## Consistency check
# - Double mass curve method

# %% [markdown]
# # Lesson 3 — Infiltration Concepts and Field Measurement
#
# ## Definitions
# - Infiltration
# - Infiltration rate
# - Infiltration capacity (under specified condition)
# - Cumulative infiltration
# - Steady-state infiltration
# - Percolation
#
# ## Controlling factors
# - Soil texture/structure
# - Vegetation and organic matter
# - Initial soil moisture
# - Rainfall intensity
# - Temperature
# - Slope
#
# ## Field/analysis methods
# - Single-ring infiltrometer
# - Double-ring infiltrometer
# - Hydrograph-based interpretation

# %% [markdown]
# # Lesson 4 — Infiltration Models and Parameter Estimation
#
# ## Example cumulative infiltration relation
# \[
# F(t)=S\,t^{1/2}+Kt
# \]
#
# ## Horton-model parameters
# - \(f_0\): initial infiltration capacity
# - \(f_c\): final/steady infiltration capacity
# - \(k\): decay constant
#
# ## Linearization workflow
# 1. Transform model equation when needed.
# 2. Plot transformed variable versus time.
# 3. Fit a straight line.
# 4. Extract constants from slope and intercept.

# %% [markdown]
# # Lesson 5 — Phi Index, Direct Runoff, and Runoff Coefficient
#
# ## Phi-index method
# - Assume constant loss rate \(\phi\)
# - Exclude rainfall intensities below \(\phi\)
# - Match rainfall excess to direct runoff depth
#
# ## Runoff coefficient
# \[
# C = rac{V_{runoff}}{V_{rainfall}}
# \]
#
# ## Unit control
# - Keep depth, area, time, and volume units consistent.

# %% [markdown]
# # Lesson 6 — Examination Technique and Answer Quality
#
# ## High-scoring answer sequence
# 1. State the required definition precisely.
# 2. List known values with units.
# 3. Choose the correct method from wording.
# 4. Write equation and define symbols.
# 5. Show substitution and conversions.
# 6. Present final answer with units and short interpretation.

# %% [markdown]
# # Consolidated Formula Sheet
#
# - Gauge density: \(N=CV^2/E^2\)
# - Coefficient of variation: \(CV=(\sigma/ar{P})	imes 100\%\)
# - Thiessen mean rainfall: \(ar{P}=\sum(A_iP_i)/A\)
# - Runoff coefficient: \(C=V_{runoff}/V_{rainfall}\)
# - Example cumulative infiltration: \(F(t)=S\,t^{1/2}+Kt\)
